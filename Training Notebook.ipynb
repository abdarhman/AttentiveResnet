# %%
from ResNet import ResNet
import tensorflow as tf
from utils import *
# Out:
# C:\Users\jumbo\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def main(phase = 'train'):

    # open session
    with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as sess:
        cnn = ResNet(sess)

        # build graph
        cnn.build_model()

        # show network architecture
        show_all_variables()

        if phase == 'train' :
            # launch the graph in a session
            cnn.train()

            print(" [*] Training finished! \n")

            cnn.test()
            print(" [*] Test finished!")

        if phase == 'test' :
            cnn.test()
            print(" [*] Test finished!")

# %%
if __name__ == '__main__':
    main()
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# network/conv/conv2d/kernel:0 (float32_ref 3x3x3x32) [864, bytes: 3456]
# network/conv/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/batch_norm_1x1_front/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/batch_norm_1x1_front/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# network/resblock0_0/conv_1x1_front/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/batch_norm_3x3/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/batch_norm_3x3/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/conv_0/conv2d/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# network/resblock0_0/conv_0/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/conv_init/conv2d/kernel:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# network/resblock0_0/conv_init/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_0/batch_norm_1x1_back/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/batch_norm_1x1_back/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_0/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# network/resblock0_0/conv_1x1_back/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_1/batch_norm_1x1_front/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_1/batch_norm_1x1_front/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_1/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# network/resblock0_1/conv_1x1_front/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_1/batch_norm_3x3/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_1/batch_norm_3x3/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_1/conv_0/conv2d/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# network/resblock0_1/conv_0/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_1/conv_init/conv2d/kernel:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# network/resblock0_1/conv_init/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_1/batch_norm_1x1_back/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_1/batch_norm_1x1_back/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_1/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# network/resblock0_1/conv_1x1_back/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_2/batch_norm_1x1_front/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_2/batch_norm_1x1_front/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_2/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x128x32) [4096, bytes: 16384]
# network/resblock0_2/conv_1x1_front/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_2/batch_norm_3x3/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_2/batch_norm_3x3/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_2/conv_0/conv2d/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# network/resblock0_2/conv_0/conv2d/bias:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_2/conv_init/conv2d/kernel:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# network/resblock0_2/conv_init/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock0_2/batch_norm_1x1_back/beta:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_2/batch_norm_1x1_back/gamma:0 (float32_ref 32) [32, bytes: 128]
# network/resblock0_2/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x32x128) [4096, bytes: 16384]
# network/resblock0_2/conv_1x1_back/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock1_0/batch_norm_1x1_front/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock1_0/batch_norm_1x1_front/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock1_0/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x128x64) [8192, bytes: 32768]
# network/resblock1_0/conv_1x1_front/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_0/batch_norm_3x3/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_0/batch_norm_3x3/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_0/conv_0/conv2d/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# network/resblock1_0/conv_0/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_0/conv_init/conv2d/kernel:0 (float32_ref 1x1x128x256) [32768, bytes: 131072]
# network/resblock1_0/conv_init/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_0/batch_norm_1x1_back/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_0/batch_norm_1x1_back/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_0/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# network/resblock1_0/conv_1x1_back/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_1/batch_norm_1x1_front/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_1/batch_norm_1x1_front/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_1/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# network/resblock1_1/conv_1x1_front/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_1/batch_norm_3x3/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_1/batch_norm_3x3/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_1/conv_0/conv2d/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# network/resblock1_1/conv_0/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_1/conv_init/conv2d/kernel:0 (float32_ref 1x1x256x256) [65536, bytes: 262144]
# network/resblock1_1/conv_init/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_1/batch_norm_1x1_back/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_1/batch_norm_1x1_back/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_1/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# network/resblock1_1/conv_1x1_back/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_2/batch_norm_1x1_front/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_2/batch_norm_1x1_front/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_2/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# network/resblock1_2/conv_1x1_front/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_2/batch_norm_3x3/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_2/batch_norm_3x3/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_2/conv_0/conv2d/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# network/resblock1_2/conv_0/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_2/conv_init/conv2d/kernel:0 (float32_ref 1x1x256x256) [65536, bytes: 262144]
# network/resblock1_2/conv_init/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_2/batch_norm_1x1_back/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_2/batch_norm_1x1_back/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_2/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# network/resblock1_2/conv_1x1_back/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_3/batch_norm_1x1_front/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_3/batch_norm_1x1_front/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_3/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x256x64) [16384, bytes: 65536]
# network/resblock1_3/conv_1x1_front/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_3/batch_norm_3x3/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_3/batch_norm_3x3/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_3/conv_0/conv2d/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# network/resblock1_3/conv_0/conv2d/bias:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_3/conv_init/conv2d/kernel:0 (float32_ref 1x1x256x256) [65536, bytes: 262144]
# network/resblock1_3/conv_init/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock1_3/batch_norm_1x1_back/beta:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_3/batch_norm_1x1_back/gamma:0 (float32_ref 64) [64, bytes: 256]
# network/resblock1_3/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x64x256) [16384, bytes: 65536]
# network/resblock1_3/conv_1x1_back/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock2_0/batch_norm_1x1_front/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock2_0/batch_norm_1x1_front/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock2_0/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x256x128) [32768, bytes: 131072]
# network/resblock2_0/conv_1x1_front/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_0/batch_norm_3x3/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_0/batch_norm_3x3/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_0/conv_0/conv2d/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# network/resblock2_0/conv_0/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_0/conv_init/conv2d/kernel:0 (float32_ref 1x1x256x512) [131072, bytes: 524288]
# network/resblock2_0/conv_init/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_0/batch_norm_1x1_back/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_0/batch_norm_1x1_back/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_0/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x128x512) [65536, bytes: 262144]
# network/resblock2_0/conv_1x1_back/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_1/batch_norm_1x1_front/beta:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_1/batch_norm_1x1_front/gamma:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_1/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x512x128) [65536, bytes: 262144]
# network/resblock2_1/conv_1x1_front/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_1/batch_norm_3x3/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_1/batch_norm_3x3/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_1/conv_0/conv2d/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# network/resblock2_1/conv_0/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_1/conv_init/conv2d/kernel:0 (float32_ref 1x1x512x512) [262144, bytes: 1048576]
# network/resblock2_1/conv_init/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_1/batch_norm_1x1_back/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_1/batch_norm_1x1_back/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_1/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x128x512) [65536, bytes: 262144]
# network/resblock2_1/conv_1x1_back/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_2/batch_norm_1x1_front/beta:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_2/batch_norm_1x1_front/gamma:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_2/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x512x128) [65536, bytes: 262144]
# network/resblock2_2/conv_1x1_front/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_2/batch_norm_3x3/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_2/batch_norm_3x3/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_2/conv_0/conv2d/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# network/resblock2_2/conv_0/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_2/conv_init/conv2d/kernel:0 (float32_ref 1x1x512x512) [262144, bytes: 1048576]
# network/resblock2_2/conv_init/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_2/batch_norm_1x1_back/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_2/batch_norm_1x1_back/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_2/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x128x512) [65536, bytes: 262144]
# network/resblock2_2/conv_1x1_back/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_3/batch_norm_1x1_front/beta:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_3/batch_norm_1x1_front/gamma:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_3/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x512x128) [65536, bytes: 262144]
# network/resblock2_3/conv_1x1_front/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_3/batch_norm_3x3/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_3/batch_norm_3x3/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_3/conv_0/conv2d/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# network/resblock2_3/conv_0/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_3/conv_init/conv2d/kernel:0 (float32_ref 1x1x512x512) [262144, bytes: 1048576]
# network/resblock2_3/conv_init/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_3/batch_norm_1x1_back/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_3/batch_norm_1x1_back/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_3/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x128x512) [65536, bytes: 262144]
# network/resblock2_3/conv_1x1_back/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_4/batch_norm_1x1_front/beta:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_4/batch_norm_1x1_front/gamma:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_4/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x512x128) [65536, bytes: 262144]
# network/resblock2_4/conv_1x1_front/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_4/batch_norm_3x3/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_4/batch_norm_3x3/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_4/conv_0/conv2d/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# network/resblock2_4/conv_0/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_4/conv_init/conv2d/kernel:0 (float32_ref 1x1x512x512) [262144, bytes: 1048576]
# network/resblock2_4/conv_init/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_4/batch_norm_1x1_back/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_4/batch_norm_1x1_back/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_4/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x128x512) [65536, bytes: 262144]
# network/resblock2_4/conv_1x1_back/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_5/batch_norm_1x1_front/beta:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_5/batch_norm_1x1_front/gamma:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_5/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x512x128) [65536, bytes: 262144]
# network/resblock2_5/conv_1x1_front/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_5/batch_norm_3x3/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_5/batch_norm_3x3/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_5/conv_0/conv2d/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# network/resblock2_5/conv_0/conv2d/bias:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_5/conv_init/conv2d/kernel:0 (float32_ref 1x1x512x512) [262144, bytes: 1048576]
# network/resblock2_5/conv_init/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock2_5/batch_norm_1x1_back/beta:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_5/batch_norm_1x1_back/gamma:0 (float32_ref 128) [128, bytes: 512]
# network/resblock2_5/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x128x512) [65536, bytes: 262144]
# network/resblock2_5/conv_1x1_back/conv2d/bias:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock_3_0/batch_norm_1x1_front/beta:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock_3_0/batch_norm_1x1_front/gamma:0 (float32_ref 512) [512, bytes: 2048]
# network/resblock_3_0/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x512x256) [131072, bytes: 524288]
# network/resblock_3_0/conv_1x1_front/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_0/batch_norm_3x3/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_0/batch_norm_3x3/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_0/conv_0/conv2d/kernel:0 (float32_ref 3x3x256x256) [589824, bytes: 2359296]
# network/resblock_3_0/conv_0/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_0/conv_init/conv2d/kernel:0 (float32_ref 1x1x512x1024) [524288, bytes: 2097152]
# network/resblock_3_0/conv_init/conv2d/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_0/batch_norm_1x1_back/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_0/batch_norm_1x1_back/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_0/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x256x1024) [262144, bytes: 1048576]
# network/resblock_3_0/conv_1x1_back/conv2d/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_1/batch_norm_1x1_front/beta:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_1/batch_norm_1x1_front/gamma:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_1/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x1024x256) [262144, bytes: 1048576]
# network/resblock_3_1/conv_1x1_front/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_1/batch_norm_3x3/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_1/batch_norm_3x3/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_1/conv_0/conv2d/kernel:0 (float32_ref 3x3x256x256) [589824, bytes: 2359296]
# network/resblock_3_1/conv_0/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_1/conv_init/conv2d/kernel:0 (float32_ref 1x1x1024x1024) [1048576, bytes: 4194304]
# network/resblock_3_1/conv_init/conv2d/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_1/batch_norm_1x1_back/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_1/batch_norm_1x1_back/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_1/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x256x1024) [262144, bytes: 1048576]
# network/resblock_3_1/conv_1x1_back/conv2d/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_2/batch_norm_1x1_front/beta:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_2/batch_norm_1x1_front/gamma:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_2/conv_1x1_front/conv2d/kernel:0 (float32_ref 1x1x1024x256) [262144, bytes: 1048576]
# network/resblock_3_2/conv_1x1_front/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_2/batch_norm_3x3/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_2/batch_norm_3x3/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_2/conv_0/conv2d/kernel:0 (float32_ref 3x3x256x256) [589824, bytes: 2359296]
# network/resblock_3_2/conv_0/conv2d/bias:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_2/conv_init/conv2d/kernel:0 (float32_ref 1x1x1024x1024) [1048576, bytes: 4194304]
# network/resblock_3_2/conv_init/conv2d/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# network/resblock_3_2/batch_norm_1x1_back/beta:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_2/batch_norm_1x1_back/gamma:0 (float32_ref 256) [256, bytes: 1024]
# network/resblock_3_2/conv_1x1_back/conv2d/kernel:0 (float32_ref 1x1x256x1024) [262144, bytes: 1048576]
# network/resblock_3_2/conv_1x1_back/conv2d/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# network/batch_norm/beta:0 (float32_ref 1024) [1024, bytes: 4096]
# network/batch_norm/gamma:0 (float32_ref 1024) [1024, bytes: 4096]
# network/logit/dense/kernel:0 (float32_ref 1024x10) [10240, bytes: 40960]
# network/logit/dense/bias:0 (float32_ref 10) [10, bytes: 40]
# Total size of variables: 9551370
# Total bytes of variables: 38205480
#  [*] Reading checkpoints...
#  [*] Failed to find a checkpoint
#  [!] Load failed...
